# %% [markdown]
# # Exercise Set 6: Data Structuring 2
#
# *Afternoon, August 15, 2018*
#
# In this Exercise Set we will continue working with the weather data you downloaded and saved in Exercise Set 4.
#
# > **_Note_**: to solve the bonus exercises in this exerise set you will need to apply the `.groupby()` method a few times. This has not yet been covered in the lectures (you will see it tomorrow).
# >
# > `.groupby()` is a method of pandas dataframes, meaning we can call it like so: `data.groupby('colname')`. The method groups your dataset by a specified column, and applies any following changes within each of these groups. For a more detailed explanation see [this link](https://www.tutorialspoint.com/python_pandas/python_pandas_groupby.htm). The [documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html) might also be useful.
#
# First load in the required modules and set up the plotting library:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise Section 6.1: Weather, part 2
#
# This section is the second part of three that analyzes NOAA data. The first part is Exercise Section 4.1, the last part is Exercise Section 7.2.

# %% [markdown]
# > **Ex. 6.1.1:** Load the CSV data you stored yesterday as part of Exercise Section 4.1. If you didn't manage to save the CSV file, you can use the code in [this gist](https://gist.github.com/Kristianuruplarsen/be3a14b226fc4c4d7b62c39de70307e4) to load in the NOAA data.

# %%
df = pd.read_csv('df_select.csv', sep=',')
print(df.head())
df['station_identifier'] = df['station_identifier'].astype(str)
df.dtypes
# Out:
#   station_identifier      date observation_type  observation_value
# 0        ITE00100550  18640101             TMAX                1.0
# 1        ITE00100550  18640101             TMIN               -2.3
# 2        ITE00100550  18640101             PRCP                2.5
# 3        ASN00079028  18640101             PRCP                0.0
# 4        USC00064757  18640101             PRCP               11.9
# station_identifier     object
# date                    int64
# observation_type       object
# observation_value     float64
# dtype: object

# %% [markdown]
# > **Ex. 6.1.2:** Convert the date formatted as string to  datetime. Make a new column with the month for each observation.

# %%
df['date'] = pd.to_datetime(df['date'] , format = '%Y%m%d')
df['month'] = df['date'].dt.month
print(df.head())
# Out:
#   station_identifier       date observation_type  observation_value  month
# 0        ITE00100550 1864-01-01             TMAX                1.0      1
# 1        ITE00100550 1864-01-01             TMIN               -2.3      1
# 2        ITE00100550 1864-01-01             PRCP                2.5      1
# 3        ASN00079028 1864-01-01             PRCP                0.0      1
# 4        USC00064757 1864-01-01             PRCP               11.9      1

# %% [markdown]
# > **Ex. 6.1.3:** Set the datetime variable as temporal index and make a timeseries plot.
#
# > _Hint:_ for this you need to know a few methods of the pandas DataFrames and pandas Series objects. Look up `.set_index()` and `.plot()`.

# %%
df.set_index('date').plot(y = 'observation_value')

# %% [markdown]
# > **Ex. 6.1.4:** Extract the country code from the station name into a separate column.
#
# > _Hint:_ The station column contains a GHCND ID, given to each weather station by NOAA. The format of these ID's is a 2-3 letter country code, followed by a integer identifying the specific station. A simple approach is to assume a fixed length of the country ID. A more complex way would be to use the [`re`](https://docs.python.org/2/library/re.html) module.

# %%
df['C_ID'] = df['station_identifier'].str[0:3]

print(df.head())
# Out:
#   station_identifier       date observation_type  observation_value  month  \
# 0        ITE00100550 1864-01-01             TMAX                1.0      1
# 1        ITE00100550 1864-01-01             TMIN               -2.3      1
# 2        ITE00100550 1864-01-01             PRCP                2.5      1
# 3        ASN00079028 1864-01-01             PRCP                0.0      1
# 4        USC00064757 1864-01-01             PRCP               11.9      1
#
#   C_ID
# 0  ITE
# 1  ITE
# 2  ITE
# 3  ASN
# 4  USC

# %%
import re
# 27341        UK000056225 1864-12-31             TMAX                1.6
# 27342        UK000056225 1864-12-31             TMIN               -1.9
# 27343        UK000056225 1864-12-31             PRCP                0.3
# 27344        ASN00026026 1864-12-31             PRCP                0.0
# 27345        ASN00089049 1864-12-31             PRCP                0.0
# 27346        SZ000006717 1864-12-31             TMAX               -6.2
# 27347        SZ000006717 1864-12-31             TMIN              -10.5
#
#        month C_ID country_code
# 0          1  ITE          ITE
# 1          1  ITE          ITE
# 2          1  ITE          ITE
# 3          1  ASN          ASN
# 4          1  USC          USC
# 5          1  SF0           SF
# 6          1  ASN          ASN
# 7          1  SWE          SWE
# 8          1  ASN          ASN
# 9          1  ASN          ASN
# 10         1  ASN          ASN
# 11         1  USP        USPCA
# 12         1  USC          USC
# 13         1  USC          USC
# 14         1  USC          USC
# 15         1  CA0           CA
# 16         1  CA0           CA
# 17         1  CA0           CA
# 18         1  CA0           CA
# 19         1  HRE          HRE
# 20         1  ASN          ASN
# 21         1  ASN          ASN
# 22         1  ASN          ASN
# 23         1  ASN          ASN
# 24         1  EIE          EIE
# 25         1  EIE          EIE
# 26         1  EIE          EIE
# 27         1  ASN          ASN
# 28         1  BE0           BE
# 29         1  BE0           BE
# ...      ...  ...          ...
# 27318     12  ASN          ASN
# 27319     12  ASN          ASN
# 27320     12  ASN          ASN
# 27321     12  ASN          ASN
# 27322     12  SW0           SW
# 27323     12  ASN          ASN
# 27324     12  AU0           AU
# 27325     12  AU0           AU
# 27326     12  GM0           GM
# 27327     12  GM0           GM
# 27328     12  GM0           GM
# 27329     12  ASN          ASN
# 27330     12  UK0           UK
# 27331     12  UK0           UK
# 27332     12  UK0           UK
# 27333     12  HR0           HR
# 27334     12  ASN          ASN
# 27335     12  ITE          ITE
# 27336     12  ITE          ITE
# 27337     12  ITE          ITE
# 27338     12  USP        USPCA
# 27339     12  ASN          ASN
# 27340     12  ASN          ASN
# 27341     12  UK0           UK
# 27342     12  UK0           UK
# 27343     12  UK0           UK
# 27344     12  ASN          ASN
# 27345     12  ASN          ASN
# 27346     12  SZ0           SZ
# 27347     12  SZ0           SZ
#
# [27348 rows x 7 columns]

# %% [markdown]
# > **Ex. 6.1.5:** Make a function that downloads and formats the weather data according to previous exercises in Exercise Section 4.1, 6.1. You should use data for ALL stations but still only select maximal temperature. _Bonus:_ To validate that your function works plot the temperature curve for each country in the same window. Use `plt.legend()` to add a legend.

# %%
import numpy as np
import re
import pandas as pd
import time
def weather(years):
    base_url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/'
    
    # downloads all weather data
    for year in years:
        # composes the url
        url = base_url + str(year) + '.csv.gz'
        
        # reads the file from the url
        df = pd.read_csv(url,
                         compression = 'gzip',
                         header = None)
        
        # selects only the relevant columns and replaces the indecies with column names
        df = df.iloc[:,:4]
        COLS = ['station_identifier', 'date', 'observation_type', 'observation_value']
        df.columns = COLS
        
        # adjusts the observation value
        df['observation_value'] = df['observation_value']/10 

        # selects only the observation for the maximum temperature
        select_type = df.observation_type == 'TMAX'
        df_select = df[select_type].copy()

        # conversion from celcius to farenheit
        df_select['TMAX_F'] = 32 + 1.8*df_select['observation_value']

        # sort by date
        df_select = df_select.sort_values(by = 'date', ascending = True)
        
        # converts integer to date time
        df_select['date'] = pd.to_datetime(df_select['date'] , format = '%Y%m%d')
        
        # creates new variable for month
        df_select['month'] = df_select['date'].dt.month
        
        # selects the country code
        df_select['country_code'] = df_select['station_identifier'].apply(lambda i: re.sub("[^a-zA-Z]*", '', i))
        
        # saves the file
        rel_path = 'weatherdata/' + str(year) + '.csv'
        df_select.to_csv(rel_path,index=False)
        
        # parses for 2 seconds such that we don't get kicked off
        print('Data for ' + str(year) + ' is downloaded... ' + str(years[-1] - year) + ' to go!')
        time.sleep(2)

# downloads datasets for the selected years
years = list(range(1864,1865))
weather(years)
# Out:
# Data for 1864 is downloaded... 0 to go!

# %%
df = pd.read_csv('weatherdata/1864.csv', sep=',')
df.set_index('date').plot(y = 'observation_value')

# %% [markdown]
# ##  Exercise Section 6.2:
#
# In this section we will use [this dataset](https://archive.ics.uci.edu/ml/datasets/Adult) from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets.html) to practice some basic operations on pandas dataframes.

# %% [markdown]
# > **Ex. 6.2.1:** This link `'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'` leads to a comma-separated file with income data from a US census. Load the data into a pandas dataframe and show the 25th to 35th row.
#
# > _Hint #1:_ There are no column names in the dataset. Use the list `['age','workclass', 'fnlwgt', 'educ', 'educ_num', 'marital_status', 'occupation','relationship', 'race', 'sex','capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'wage']` as names.
#
# > _Hint #2:_ When you read in the csv, you might find that pandas includes whitespace in all of the cells. To get around this include the argument `skipinitialspace = True` to `read_csv()`.

# %%
import pandas as pd

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
col = ['age','workclass', 'fnlwgt', 'educ', 'educ_num', 'marital_status', 'occupation','relationship', 
       'race', 'sex','capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'wage']
data = pd.read_csv(url, header = None ,skipinitialspace = True)

data.columns = col
print(data.iloc[24:35])
# Out:
#     age    workclass  fnlwgt          educ  educ_num      marital_status  \
# 24   59      Private  109015       HS-grad         9            Divorced
# 25   56    Local-gov  216851     Bachelors        13  Married-civ-spouse
# 26   19      Private  168294       HS-grad         9       Never-married
# 27   54            ?  180211  Some-college        10  Married-civ-spouse
# 28   39      Private  367260       HS-grad         9            Divorced
# 29   49      Private  193366       HS-grad         9  Married-civ-spouse
# 30   23    Local-gov  190709    Assoc-acdm        12       Never-married
# 31   20      Private  266015  Some-college        10       Never-married
# 32   45      Private  386940     Bachelors        13            Divorced
# 33   30  Federal-gov   59951  Some-college        10  Married-civ-spouse
# 34   22    State-gov  311512  Some-college        10  Married-civ-spouse
#
#          occupation   relationship                race     sex  capital_gain  \
# 24     Tech-support      Unmarried               White  Female             0
# 25     Tech-support        Husband               White    Male             0
# 26     Craft-repair      Own-child               White    Male             0
# 27                ?        Husband  Asian-Pac-Islander    Male             0
# 28  Exec-managerial  Not-in-family               White    Male             0
# 29     Craft-repair        Husband               White    Male             0
# 30  Protective-serv  Not-in-family               White    Male             0
# 31            Sales      Own-child               Black    Male             0
# 32  Exec-managerial      Own-child               White    Male             0
# 33     Adm-clerical      Own-child               White    Male             0
# 34    Other-service        Husband               Black    Male             0
#
#     capital_loss  hours_per_week native_country   wage
# 24             0              40  United-States  <=50K
# 25             0              40  United-States   >50K
# 26             0              40  United-States  <=50K
# 27             0              60          South   >50K
# 28             0              80  United-States  <=50K
# 29             0              40  United-States  <=50K
# 30             0              52  United-States  <=50K
# 31             0              44  United-States  <=50K
# 32          1408              40  United-States  <=50K
# 33             0              40  United-States  <=50K
# 34             0              15  United-States  <=50K

# %% [markdown]
# > **Ex. 6.2.2:** What is the missing value sign in this dataset? Replace all missing values with NA's understood by pandas. Then proceed to drop all rows containing any missing values with the `dropna` method. How many rows are removed in this operation?
#
# > _Hint 1:_ if this doesn't work as expected you might want to take a look at the hint for 6.2.1 again.
#
# > _Hint 2:_ The NaN method from NumPy might be useful

# %%
data_r = data.replace({'?':None})
print(data_r.isnull().sum())
print()
data_rm = data_r.dropna()
print(data_rm.isnull().sum())
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# educ                 0
# educ_num             0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# wage                 0
# dtype: int64
#
# age               0
# workclass         0
# fnlwgt            0
# educ              0
# educ_num          0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# wage              0
# dtype: int64

# %% [markdown]
# > **Ex. 6.2.3:** (_Bonus_) Is there any evidence of a gender-wage-gap in the data? Create a table showing the percentage of men and women earning more than 50K a year.

# %%
select = data_rm.wage == '>50K'
data_50K = data_rm[select] 

data_50K.groupby(['wage','sex']).count()
# Out:
#               age  workclass  fnlwgt  educ  educ_num  marital_status  \
# wage sex
# >50K Female  1112       1112    1112  1112      1112            1112
#      Male    6396       6396    6396  6396      6396            6396
#
#              occupation  relationship  race  capital_gain  capital_loss  \
# wage sex
# >50K Female        1112          1112  1112          1112          1112
#      Male          6396          6396  6396          6396          6396
#
#              hours_per_week  native_country
# wage sex
# >50K Female            1112            1112
#      Male              6396            6396

# %% [markdown]
# > **Ex. 6.2.4:** (_Bonus_) Group the data by years of education (`educ_num`) and marital status. Now plot the share of individuals who earn more than 50K for the two groups 'Divorced' and 'Married-civ-spouse' (normal marriage). Your final result should look like this:
#
# ![](examplefig.png)
#
# > _Hint:_ the `.query()` method is extremely useful for filtering data.

# %%
data_gr = data_50K.groupby(['educ_num', 'marital_status'])
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# educ_num  marital_status
# 2         Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
# 3         Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
#           Never-married            AxesSubplot(0.125,0.125;0.775x0.755)
# 4         Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-spouse-absent    AxesSubplot(0.125,0.125;0.775x0.755)
#           Never-married            AxesSubplot(0.125,0.125;0.775x0.755)
#           Widowed                  AxesSubplot(0.125,0.125;0.775x0.755)
# 5         Divorced                 AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
#           Never-married            AxesSubplot(0.125,0.125;0.775x0.755)
#           Widowed                  AxesSubplot(0.125,0.125;0.775x0.755)
# 6         Divorced                 AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
#           Never-married            AxesSubplot(0.125,0.125;0.775x0.755)
#           Separated                AxesSubplot(0.125,0.125;0.775x0.755)
#           Widowed                  AxesSubplot(0.125,0.125;0.775x0.755)
# 7         Divorced                 AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
#           Never-married            AxesSubplot(0.125,0.125;0.775x0.755)
#           Widowed                  AxesSubplot(0.125,0.125;0.775x0.755)
# 8         Divorced                 AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
#           Never-married            AxesSubplot(0.125,0.125;0.775x0.755)
#           Widowed                  AxesSubplot(0.125,0.125;0.775x0.755)
# 9         Divorced                 AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-AF-spouse        AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-spouse-absent    AxesSubplot(0.125,0.125;0.775x0.755)
#           Never-married            AxesSubplot(0.125,0.125;0.775x0.755)
#           Separated                AxesSubplot(0.125,0.125;0.775x0.755)
#                                                    ...
# 12        Divorced                 AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
#           Never-married            AxesSubplot(0.125,0.125;0.775x0.755)
#           Separated                AxesSubplot(0.125,0.125;0.775x0.755)
#           Widowed                  AxesSubplot(0.125,0.125;0.775x0.755)
# 13        Divorced                 AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-AF-spouse        AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-spouse-absent    AxesSubplot(0.125,0.125;0.775x0.755)
#           Never-married            AxesSubplot(0.125,0.125;0.775x0.755)
#           Separated                AxesSubplot(0.125,0.125;0.775x0.755)
#           Widowed                  AxesSubplot(0.125,0.125;0.775x0.755)
# 14        Divorced                 AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-spouse-absent    AxesSubplot(0.125,0.125;0.775x0.755)
#           Never-married            AxesSubplot(0.125,0.125;0.775x0.755)
#           Separated                AxesSubplot(0.125,0.125;0.775x0.755)
#           Widowed                  AxesSubplot(0.125,0.125;0.775x0.755)
# 15        Divorced                 AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-spouse-absent    AxesSubplot(0.125,0.125;0.775x0.755)
#           Never-married            AxesSubplot(0.125,0.125;0.775x0.755)
#           Separated                AxesSubplot(0.125,0.125;0.775x0.755)
#           Widowed                  AxesSubplot(0.125,0.125;0.775x0.755)
# 16        Divorced                 AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-civ-spouse       AxesSubplot(0.125,0.125;0.775x0.755)
#           Married-spouse-absent    AxesSubplot(0.125,0.125;0.775x0.755)
#           Never-married            AxesSubplot(0.125,0.125;0.775x0.755)
#           Separated                AxesSubplot(0.125,0.125;0.775x0.755)
#           Widowed                  AxesSubplot(0.125,0.125;0.775x0.755)
# Length: 74, dtype: object
